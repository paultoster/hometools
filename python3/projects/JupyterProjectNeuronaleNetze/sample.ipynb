# %% [markdown]
# # This is a sample Jupyter Notebook
#
# Below is an example of a code cell.
# Put your cursor into the cell and press Shift+Enter to execute it and select the next one, or click 'Run Cell' button.
#
# Press Double Shift to search everywhere for classes, files, tool windows, actions, and settings.
#
# To learn more about Jupyter Notebooks in PyCharm, see [help](https://www.jetbrains.com/help/pycharm/ipython-notebook-support.html).
# For an overview of PyCharm, go to Help -> Learn IDE features or refer to [our documentation](https://www.jetbrains.com/help/pycharm/getting-started.html).
#
# Das ist ein ***Test*** mit "Formatierungszeichen"
#
# 1. Liste
# 2. beliebige Nummer
# 1. bei Übersetzen korrigiert
#     1. SubListe einrücken
#
# Absätze mit Leerzeile
# Zeilenumbrüche durch zwei Leerzeichen einer  Zeile
#
# Weblinks [Json-Seite](http://www.json.org)
#
# Ende

# %%
print("Hello World!")

a="Das ist unser erster Python-Code und wir grüßen die Welt und besonders unsere Leser"
print(a)
# Out:
# Hello World!
# Das ist unser erster Python-Code und wir grüßen die Welt und besonders unsere Leser

# %%
def fehlerfunc(x,y):
    return x/y

def avg_beelength(valuelist):
    total = sum(valuelist)
    count = len(valuelist)
    return fehlerfunc(total,count)

bees = (3,3.5,4.1,5.2,5,2)
nobees = ()
# %xmode Verbose
avg_beelength(nobees)
# Out:
# Exception reporting mode: Verbose
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[14], line 12
#      10 nobees = ()
#      11 get_ipython().run_line_magic('xmode', 'Verbose')
# ---> 12 avg_beelength(nobees)
#         nobees = ()
#
# Cell In[14], line 7, in avg_beelength(valuelist=())
#       5 total = sum(valuelist)
#       6 count = len(valuelist)
# ----> 7 return fehlerfunc(total,count)
#         total = 0
#         count = 0
#
# Cell In[14], line 2, in fehlerfunc(x=0, y=0)
#       1 def fehlerfunc(x,y):
# ----> 2     return x/y
#         x = 0
#         y = 0
#
# ZeroDivisionError: division by zero
